# %% [markdown]
# <a href="https://colab.research.google.com/github/danenveiga-boop/Alura/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Estilo

* {
    margin: 0;
    padding: 0;
    box-sizing: border-box;
}

body {
    font-family: Arial, sans-serif;
    background-color: #f2f4f7;
}

.cabeçalho {
    padding: 15px 25px;
    background-color: #173f5f;
    color: white;
}

.cabeçalho a {
    color: white;
}

main h2 {
    margin-top: 30px;
    text-align: center;
}

/* Área completa do flashcard */
.cartao {
    width: 300px;
    height: 260px;
    margin: 30px auto;
    perspective: 1000px;
}

/* Parte responsável pelo movimento */
.cartao-interno {
    position: relative;
    width: 100%;
    height: 100%;
    transition: transform 0.8s;
    transform-style: preserve-3d;
}

/* Faz o cartão virar */
.cartao:hover .cartao-interno {
    transform: rotateY(180deg);
}

/* Configuração da frente e do verso */
.cartao-frente,
.cartao-verso {
    position: absolute;
    width: 100%;
    height: 100%;
    border-radius: 12px;
    overflow: hidden;
    backface-visibility: hidden;
    box-shadow: 0 4px 10px rgba(0, 0, 0, 0.25);
    text-align: center;
    background-color: white;
}

/* Deixa o verso inicialmente virado */
.cartao-verso {
    transform: rotateY(180deg);
    background-color: #d8f3dc;
}

/* Ajusta a imagem dentro do cartão */
.cartao-imagem {
    width: 100%;
    height: 190px;
    object-fit: contain;
    display: block;
    background-color: #dcecf5;
}

.cartao {
    width: 300px;
    height: 260px;
    margin: 30px auto;
    perspective: 1000px;
}
.cartao-frente p,
.cartao-verso p {
    position: absolute;
    left: 0;
    right: 0;
    bottom: 10px;
    margin: 0;
    padding: 0 12px;
    text-align: center;
}

.cartao-frente p {
    font-weight: bold;
}

header {
    width: 100%;
    display: flex;
    flex-direction: column;
    align-items: center;
    text-align: center;
}

header h1 {
    margin: 0;
}



HTML

<body>
  <header class="cabecalho">
    <h1>Confere Aí</h1>

    <nav>
      <link rel="stylesheet" href="Estilo.css">
    </nav>
  </header>

  <main>
    <h2>Descubra a verdade passando o mouse</h2>

    <article class="cartao">
      <div class="cartao-interno">

        <div class="cartao-frente">
          <img
            src="https://static.nationalgeographicbrasil.com/files/styles/image_3200/public/mm1012723121410486.jpg?w=1900&amp;h=2849"
            alt="Pinguins"
            class="cartao-imagem"
          >
          <p>Mito ou verdade: pinguins conseguem voar como pássaros?</p>
        </div>

        <div class="cartao-verso">
          <img
            src="https://static.nationalgeographicbrasil.com/files/styles/image_3200/public/mm1012723121410486.jpg?w=1900&amp;h=2849"
            alt="Pinguins"
            class="cartao-imagem"
          >
          <p><strong>Mito!</strong> Pinguins não voam, mas são excelentes nadadores.</p>
        </div>

      </div>
    </article>
  </main>

  <footer>
    <p>Projeto feito por Danilo</p>
  </footer>
</body>
</html>
